# %%
#Importing libraries
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import sys
from glob import glob
from keras.preprocessing import image
from tensorflow.keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Input
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from glob import glob
from tensorflow.keras.preprocessing import image

# %%
# mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = '/content/drive/MyDrive/AI-2/project'

# %%
#Number of images in each subdir 
split_dirs = ['test','train','validate']
label_dirs = ['cube','cylinder','sphere']
for dir_name in split_dirs:
    for label_dir in label_dirs:
        print(dir_name ,label_dir, len(os.listdir('/content/drive/MyDrive/AI-2/project/synthetic_shape_data_all' + '/' + dir_name + '/' + label_dir)))
# Out:
# test cube 2
# test cylinder 2
# test sphere 2
# train cube 16
# train cylinder 21
# train sphere 16
# validate cube 2
# validate cylinder 2
# validate sphere 2

# %%
# Preprocessing the image into a 4D tensor
img_path_train = glob(DATA_DIR+'/synthetic_shape_data_all'+'/train/*/*/*.png')
img_path_validate = glob(DATA_DIR+'/synthetic_shape_data_all'+'/validate/*/*/*.png')
img_path_test = glob(DATA_DIR+'/synthetic_shape_data_all'+'/test/*/*/*.png')

print(len(img_path_train))
print(len(img_path_validate))
print(len(img_path_test))
print(img_path_train[0])
print(img_path_validate[0])
print(img_path_test[0])

img = image.load_img(img_path_train[0])
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
#img_tensor /= 255.

print(img_tensor.shape)
type(img_tensor[0])
# Out:
# 5241
# 600
# 597
# /content/drive/MyDrive/AI-2/project/synthetic_shape_data_all/train/cube/cub_L003_W003_H003/synth_cub_L003_W003_H003_X-0251_Y+0849_Z+0139_a008_b330_c175_D1_1506_D2_1786_D3_1399_D4_1705.png
# /content/drive/MyDrive/AI-2/project/synthetic_shape_data_all/validate/cylinder/cyl_L050_W020_H020/synth_cyl_L050_W020_H020_X-0228_Y+1150_Z+0286_a241_b246_c055_D1_1251_D2_1549_D3_1452_D4_1722.png
# /content/drive/MyDrive/AI-2/project/synthetic_shape_data_all/test/sphere/sph_D047/synth_sph_L047_W047_H047_X-0213_Y+0676_Z-0487_a259_b318_c032_D1_2083_D2_2267_D3_1902_D4_2106.png
# (1, 142, 142, 3)
# numpy.ndarray

# %%
train_index = list(range(5241))
validate_index = list(range(600))
test_index = list(range(597))

# %%
import pandas as pd

# %%
train_data = pd.DataFrame(columns = ['cube','cylinder','sphere','L','W','H','X','Y','Z','a','b','c','D1','D2','D3','D4','image'], index=train_index)
validate_data = pd.DataFrame(columns = ['cube','cylinder','sphere','L','W','H','X','Y','Z','a','b','c','D1','D2','D3','D4','image'], index=validate_index)
test_data = pd.DataFrame(columns = ['cube','cylinder','sphere','L','W','H','X','Y','Z','a','b','c','D1','D2','D3','D4','image'], index=test_index)

# %%
c = 0
for i in img_path_train:
  features_list = []
  p = i.split('/')
  name = p[-1]
  # print(p[8])
  if p[8] == 'cube':
    features_list.append(1)
    features_list.append(0)
    features_list.append(0)
  elif p[8] == 'cylinder':
    features_list.append(0)
    features_list.append(1)
    features_list.append(0)
  else:
    features_list.append(0)
    features_list.append(0)
    features_list.append(1)
  # print(name)
  features = name.split('_')
  # print(features)
  features_list.append(features[2][1:])
  features_list.append(features[3][1:])
  features_list.append(features[4][1:])
  features_list.append(features[5][1:])
  features_list.append(features[6][1:])
  features_list.append(features[7][1:])
  features_list.append(features[8][1:])
  features_list.append(features[9][1:])
  features_list.append(features[10][1:])
  features_list.append(features[12])
  features_list.append(features[14])
  features_list.append(features[16])
  features_list.append(features[18][:-4])
  features_list.append(i)
  train_data.loc[c] = features_list
  c = c+1

# %%
train_data
# Out:
#      cube cylinder  ...    D4                                              image
# 0       1        0  ...  1705  /content/drive/MyDrive/AI-2/project/synthetic_...
# 1       1        0  ...  2074  /content/drive/MyDrive/AI-2/project/synthetic_...
# 2       1        0  ...  1833  /content/drive/MyDrive/AI-2/project/synthetic_...
# 3       1        0  ...  1700  /content/drive/MyDrive/AI-2/project/synthetic_...
# 4       1        0  ...  2217  /content/drive/MyDrive/AI-2/project/synthetic_...
# ...   ...      ...  ...   ...                                                ...
# 5236    0        0  ...  1705  /content/drive/MyDrive/AI-2/project/synthetic_...
# 5237    0        0  ...  2179  /content/drive/MyDrive/AI-2/project/synthetic_...
# 5238    0        0  ...  1539  /content/drive/MyDrive/AI-2/project/synthetic_...
# 5239    0        0  ...  1253  /content/drive/MyDrive/AI-2/project/synthetic_...
# 5240    0        0  ...  1872  /content/drive/MyDrive/AI-2/project/synthetic_...
#
# [5241 rows x 17 columns]

# %%
c = 0
for i in img_path_validate:
  features_list = []
  p = i.split('/')
  name = p[-1]
  # print(p[8])
  if p[8] == 'cube':
    features_list.append(1)
    features_list.append(0)
    features_list.append(0)
  elif p[8] == 'cylinder':
    features_list.append(0)
    features_list.append(1)
    features_list.append(0)
  else:
    features_list.append(0)
    features_list.append(0)
    features_list.append(1)
  # print(name)
  features = name.split('_')
  # print(features)
  features_list.append(features[2][1:])
  features_list.append(features[3][1:])
  features_list.append(features[4][1:])
  features_list.append(features[5][1:])
  features_list.append(features[6][1:])
  features_list.append(features[7][1:])
  features_list.append(features[8][1:])
  features_list.append(features[9][1:])
  features_list.append(features[10][1:])
  features_list.append(features[12])
  features_list.append(features[14])
  features_list.append(features[16])
  features_list.append(features[18][:-4])
  features_list.append(i)
  validate_data.loc[c] = features_list
  c = c+1

# %%
validate_data
# Out:
#     cube cylinder  ...    D4                                              image
# 0      0        1  ...  1722  /content/drive/MyDrive/AI-2/project/synthetic_...
# 1      0        1  ...  1833  /content/drive/MyDrive/AI-2/project/synthetic_...
# 2      0        1  ...  2284  /content/drive/MyDrive/AI-2/project/synthetic_...
# 3      0        1  ...  2278  /content/drive/MyDrive/AI-2/project/synthetic_...
# 4      0        1  ...  1671  /content/drive/MyDrive/AI-2/project/synthetic_...
# ..   ...      ...  ...   ...                                                ...
# 595    0        0  ...  1247  /content/drive/MyDrive/AI-2/project/synthetic_...
# 596    0        0  ...  1571  /content/drive/MyDrive/AI-2/project/synthetic_...
# 597    0        0  ...  1659  /content/drive/MyDrive/AI-2/project/synthetic_...
# 598    0        0  ...  2261  /content/drive/MyDrive/AI-2/project/synthetic_...
# 599    0        0  ...  1900  /content/drive/MyDrive/AI-2/project/synthetic_...
#
# [600 rows x 17 columns]

# %%
c = 0
for i in img_path_test:
  features_list = []
  p = i.split('/')
  name = p[-1]
  # print(p[8])
  if p[8] == 'cube':
    features_list.append(1)
    features_list.append(0)
    features_list.append(0)
  elif p[8] == 'cylinder':
    features_list.append(0)
    features_list.append(1)
    features_list.append(0)
  else:
    features_list.append(0)
    features_list.append(0)
    features_list.append(1)
  # print(name)
  features = name.split('_')
  # print(features)
  features_list.append(features[2][1:])
  features_list.append(features[3][1:])
  features_list.append(features[4][1:])
  features_list.append(features[5][1:])
  features_list.append(features[6][1:])
  features_list.append(features[7][1:])
  features_list.append(features[8][1:])
  features_list.append(features[9][1:])
  features_list.append(features[10][1:])
  features_list.append(features[12])
  features_list.append(features[14])
  features_list.append(features[16])
  features_list.append(features[18][:-4])
  features_list.append(i)
  test_data.loc[c] = features_list
  c = c+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1ba9dd4c653f> in <module>()
#       1 c = 0
# ----> 2 for i in img_path_test:
#       3   features_list = []
#       4   p = i.split('/')
#       5   name = p[-1]
#
# NameError: name 'img_path_test' is not defined

# %%
img_path_test[300].split('/')
# Out:
# ['',
#  'content',
#  'drive',
#  'MyDrive',
#  'AI-2',
#  'project',
#  'synthetic_shape_data_all',
#  'test',
#  'cube',
#  'cub_L045_W045_H045',
#  'synth_cub_L045_W045_H045_X-0294_Y+0812_Z-0701_a100_b161_c020_D1_2171_D2_2409_D3_2099_D4_2351.png']

# %%
test_data
# Out:
#     cube cylinder  ...    D4                                              image
# 0      0        0  ...  2106  /content/drive/MyDrive/AI-2/project/synthetic_...
# 1      0        0  ...  1985  /content/drive/MyDrive/AI-2/project/synthetic_...
# 2      0        0  ...  1701  /content/drive/MyDrive/AI-2/project/synthetic_...
# 3      0        0  ...  2488  /content/drive/MyDrive/AI-2/project/synthetic_...
# 4      0        0  ...  1606  /content/drive/MyDrive/AI-2/project/synthetic_...
# ..   ...      ...  ...   ...                                                ...
# 592    0        1  ...  1564  /content/drive/MyDrive/AI-2/project/synthetic_...
# 593    0        1  ...  2013  /content/drive/MyDrive/AI-2/project/synthetic_...
# 594    0        1  ...  1570  /content/drive/MyDrive/AI-2/project/synthetic_...
# 595    0        1  ...  1655  /content/drive/MyDrive/AI-2/project/synthetic_...
# 596    0        1  ...  2243  /content/drive/MyDrive/AI-2/project/synthetic_...
#
# [597 rows x 17 columns]

# %%
test_data['L'].unique()
# Out:
# array(['047', '050', '045'], dtype=object)

# %%
test_data['W'].unique()
# Out:
# array(['047', '050', '045', '040'], dtype=object)

# %%
test_data['H'].unique()
# Out:
# array(['047', '050', '045', '040'], dtype=object)

# %%
from PIL import Image

# %%
def create_4_images(path):
  im = Image.open(path)
  width,height = im.size
  images = []
  left = 0
  top = 0
  right = width/2
  bottom = height/2
  imfi = im.crop((left, top, right, bottom))
  images.append(imfi)
  left = width/2
  top = 0
  right = width
  bottom = height/2
  imf2 = im.crop((left, top, right, bottom))
  images.append(imf2)
  left = 0
  top = height/2
  right = width/2
  bottom = height
  imf3 = im.crop((left, top, right, bottom))
  images.append(imf3)
  left = width/2
  top = height/2
  right = width
  bottom = height
  imf4 = im.crop((left, top, right, bottom))
  images.append(imf4)
  return images

# %%
img = Image.open(train_data['image'][0])
plt.imshow(img)

# %%
arrayofimages = create_4_images(train_data['image'][0])
plt.imshow(arrayofimages[3])

# %%
#creating batches
test_data.shape[0]
# Out:
# 597

# %%
# def pick_records(dataframe):
#   list_of_indexes = []
#   indexes = []
#   unique_cube = [0,1]
#   unique_cylinder = [0,1]
#   unique_sphere = [0,1]
#   unique_L = dataframe['L'].unique()
#   unique_W = dataframe['W'].unique()
#   unique_H = dataframe['H'].unique()
#   for c in [0,1]:
#     for sh in [0,1]:
#       for cyl in [0,1]:
#         for l in unique_L:
#           for w in unique_W:
#             for h in unique_H:
#                 create_channel(no_of_channels,dataframe,cube,sphere,cylinder,l,w,h,start,end)

# %%
df = test_data[test_data['cube']==1]
df = df[df['L']=='047']
df = df[df['W']=='047']
df = df[df['H']=='047']
df
# Out:
#     cube cylinder  ...    D4                                              image
# 197    1        0  ...  2363  /content/drive/MyDrive/AI-2/project/synthetic_...
# 198    1        0  ...  2413  /content/drive/MyDrive/AI-2/project/synthetic_...
# 199    1        0  ...  2255  /content/drive/MyDrive/AI-2/project/synthetic_...
# 200    1        0  ...  1983  /content/drive/MyDrive/AI-2/project/synthetic_...
# 201    1        0  ...  1983  /content/drive/MyDrive/AI-2/project/synthetic_...
# ..   ...      ...  ...   ...                                                ...
# 292    1        0  ...  2228  /content/drive/MyDrive/AI-2/project/synthetic_...
# 293    1        0  ...  1856  /content/drive/MyDrive/AI-2/project/synthetic_...
# 294    1        0  ...  2021  /content/drive/MyDrive/AI-2/project/synthetic_...
# 295    1        0  ...  1583  /content/drive/MyDrive/AI-2/project/synthetic_...
# 296    1        0  ...  1167  /content/drive/MyDrive/AI-2/project/synthetic_...
#
# [100 rows x 17 columns]

# %%
df['image'].index
# Out:
# Int64Index([197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209,
#             210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222,
#             223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235,
#             236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248,
#             249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261,
#             262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274,
#             275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287,
#             288, 289, 290, 291, 292, 293, 294, 295, 296],
#            dtype='int64')

# %%
len(df['image'].index)
# Out:
# 100

# %%
channels = []
for i in df['image']:
  arrayofimages = create_4_images(i)
  channels.append(arrayofimages[0])
  channels.append(arrayofimages[1])
  channels.append(arrayofimages[2])
  channels.append(arrayofimages[3])

# %%
len(channels)
# Out:
# 400

# %%
import random

# %%
def pickrandom(no_of_channels,indexes):
  randomlist = []
  for i in range(no_of_channels):
    n = random.randint(0,len(indexes))
    randomlist.append(indexes[n])
  return randomlist

# %%
pick = pickrandom(16,df['image'].index)
pick
# Out:
# [271,
#  264,
#  275,
#  249,
#  225,
#  279,
#  234,
#  200,
#  241,
#  216,
#  257,
#  269,
#  214,
#  282,
#  211,
#  255]

# %%
df = df.loc[pick]
df
# Out:
#     cube cylinder  ...    D4                                              image
# 271    1        0  ...  1671  /content/drive/MyDrive/AI-2/project/synthetic_...
# 264    1        0  ...  2394  /content/drive/MyDrive/AI-2/project/synthetic_...
# 275    1        0  ...  1824  /content/drive/MyDrive/AI-2/project/synthetic_...
# 249    1        0  ...  1192  /content/drive/MyDrive/AI-2/project/synthetic_...
# 225    1        0  ...  2569  /content/drive/MyDrive/AI-2/project/synthetic_...
# 279    1        0  ...  2221  /content/drive/MyDrive/AI-2/project/synthetic_...
# 234    1        0  ...  2152  /content/drive/MyDrive/AI-2/project/synthetic_...
# 200    1        0  ...  1983  /content/drive/MyDrive/AI-2/project/synthetic_...
# 241    1        0  ...  2592  /content/drive/MyDrive/AI-2/project/synthetic_...
# 216    1        0  ...  2238  /content/drive/MyDrive/AI-2/project/synthetic_...
# 257    1        0  ...  2391  /content/drive/MyDrive/AI-2/project/synthetic_...
# 269    1        0  ...  1815  /content/drive/MyDrive/AI-2/project/synthetic_...
# 214    1        0  ...  2445  /content/drive/MyDrive/AI-2/project/synthetic_...
# 282    1        0  ...  1818  /content/drive/MyDrive/AI-2/project/synthetic_...
# 211    1        0  ...  1814  /content/drive/MyDrive/AI-2/project/synthetic_...
# 255    1        0  ...  1832  /content/drive/MyDrive/AI-2/project/synthetic_...
#
# [16 rows x 17 columns]

# %%
# def create_channel(no_of_channels,dataframe,cube,sphere,cylinder,l,w,h,start,end):
#   channels = []
#   no_of_images = no_of_channels/4
#   df = dataframe[dataframe['cube']==cube]
#   df = df[df['cylinder']==cylinder]
#   df = df[df['sphere']==sphere]
#   df = df[df['L']==l]
#   df = df[df['W']==w]
#   df = df[df['H']==h]
#   df = df[start:end]
#   for i in df['image']:
#     arrayofimages = create_4_images(i)
#     channels.append(arrayofimages[0])
#     channels.append(arrayofimages[1])
#     channels.append(arrayofimages[2])
#     channels.append(arrayofimages[3])
#   return channels

# %%
def create_channel(no_of_channels,dataframe,cube,sphere,cylinder,l,w,h):
  channels = []
  no_of_images = no_of_channels/4
  no_of_images = int(no_of_images)
  df = dataframe[dataframe['cube']==cube]
  df = df[df['cylinder']==cylinder]
  df = df[df['sphere']==sphere]
  df = df[df['L']==l]
  df = df[df['W']==w]
  df = df[df['H']==h]
  indexes = df['image'].index
  ind = pickrandom(no_of_images,indexes)
  df = df.loc[ind]
  for i in df['image']:
    arrayofimages = create_4_images(i)
    channels.append(arrayofimages[0])
    channels.append(arrayofimages[1])
    channels.append(arrayofimages[2])
    channels.append(arrayofimages[3])
  return df,channels

# %%
df,channels = create_channel(20,test_data,1,0,0,'047','047','047')

# %%
df
# Out:
#     cube cylinder  ...    D4                                              image
# 229    1        0  ...  1864  /content/drive/MyDrive/AI-2/project/synthetic_...
# 289    1        0  ...  1903  /content/drive/MyDrive/AI-2/project/synthetic_...
# 223    1        0  ...  2545  /content/drive/MyDrive/AI-2/project/synthetic_...
# 210    1        0  ...  1793  /content/drive/MyDrive/AI-2/project/synthetic_...
# 212    1        0  ...  2448  /content/drive/MyDrive/AI-2/project/synthetic_...
#
# [5 rows x 17 columns]

# %%
channels[7]
# Out:
# <PIL.Image.Image image mode=1 size=71x71 at 0x7FECD3D4EE10>

# %%
def create_all_channels_for_df(no_of_channels,dataframe):
  list_of_channels = []
  list_of_df = []
  no_of_images = no_of_channels/4
  for c in [0,1]:
    for sh in [0,1]:
      for cyl in [0,1]:
        for l in dataframe['L'].unique():
          for w in dataframe['W'].unique():
            for h in dataframe['H'].unique():
              indexes = list(dataframe['image'].index)
              i = 0
              while(i<len(indexes)):
                start = indexes[i]
                i = i + int(no_of_images)
                if i<len(indexes):
                  end = indexes[i] 
                  df,channels = create_channel(no_of_channels,dataframe,c,sh,cyl,l,w,h)
                  if channels != []:
                    list_of_channels.append(channels)
                    list_of_df.append(df)
                else:
                  end = indexes[-1]
                  df,channels = create_channel(no_of_channels,dataframe,c,sh,cyl,l,w,h)
                  if channels != []:
                    list_of_channels.append(channels)
                    list_of_df.append(df)
  return list_of_channels

# %%
# no_of_channels = 20
# list_of_channels = []
# no_of_images = no_of_channels/4
# for c in [0,1]:
#   for sh in [0,1]:
#     for cyl in [0,1]:
#       for l in test_data['L'].unique():
#         for w in test_data['W'].unique():
#           for h in test_data['H'].unique():
#             indexes = list(test_data['image'].index)
#             i = 0
#             while(i<len(indexes)):
#               start = indexes[i]
#               i = i + int(no_of_images)
#               if i<len(indexes):
#                 end = indexes[i]
#                 channels = create_channel(no_of_channels,test_data,c,sh,cyl,l,w,h,start,end)
#                 if channels != []:
#                   list_of_channels.append(channels)
#               else:
#                 end = indexes[-1]
#                 channels = create_channel(no_of_channels,test_data,c,sh,cyl,l,w,h,start,end)
#                 if channels != []:
#                   list_of_channels.append(channels)

# %%
# channels = create_channel(20,test_data,1,0,0,'047','047','047')

# %%
# no_of_channels = 20
# list_of_channels = {}
# title = ""
# no_of_images = no_of_channels/4
# for c in [0,1]:
#   title = title + str(c) + "_"
#   for sh in [0,1]:
#     title = title + str(sh)+ "_"
#     for cyl in [0,1]:
#       title = title + str(cyl)+ "_"
#       for l in test_data['L'].unique():
#         title = title + str(l)+ "_"
#         for w in test_data['W'].unique():
#           title = title + str(w)+ "_"
#           for h in test_data['H'].unique():
#             title = title + str(h)+ "_"
#             indexes = list(test_data['image'].index)
#             i = 0
#             while(i<len(indexes)):
#               start = indexes[i]
#               i = i + int(no_of_images)
#               if i<len(indexes):
#                 end = indexes[i]
#                 title = title + str(start)+ "_"+ str(end) 
#                 channels = create_channel(no_of_channels,test_data,c,sh,cyl,l,w,h,start,end)
#                 if channels != []:
#                   list_of_channels[title] = channels
#               else:
#                 end = indexes[-1]
#                 title = title + str(start)+ "_"+ str(end) 
#                 channels = create_channel(no_of_channels,test_data,c,sh,cyl,l,w,h,start,end)
#                 if channels != []:
#                   list_of_channels[title] = channels
#             break

# %%
# list_of_df,list_of_channels = create_all_channels_for_df(20,test_data)
